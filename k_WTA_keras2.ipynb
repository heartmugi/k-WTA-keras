# %% [markdown]
# # 準備

# %% [markdown]
# ## artのインストール

# %%
# !pip3 install adversarial-robustness-toolbox
# Out:
# Collecting adversarial-robustness-toolbox
#   Downloading adversarial_robustness_toolbox-1.8.1-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 4.3 MB/s
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.7/dist-packages (from adversarial-robustness-toolbox) (1.19.5)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from adversarial-robustness-toolbox) (1.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from adversarial-robustness-toolbox) (4.62.3)
# Requirement already satisfied: scikit-learn<1.1.0,>=0.22.2 in /usr/local/lib/python3.7/dist-packages (from adversarial-robustness-toolbox) (0.22.2.post1)
# Collecting numba>=0.53.1
#   Downloading numba-0.54.1-cp37-cp37m-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 34.7 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from adversarial-robustness-toolbox) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from adversarial-robustness-toolbox) (57.4.0)
# Collecting llvmlite<0.38,>=0.37.0rc1
#   Downloading llvmlite-0.37.0-cp37-cp37m-manylinux2014_x86_64.whl (26.3 MB)
#      |████████████████████████████████| 26.3 MB 92 kB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<1.1.0,>=0.22.2->adversarial-robustness-toolbox) (1.0.1)
# Installing collected packages: llvmlite, numba, adversarial-robustness-toolbox
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.34.0
#     Uninstalling llvmlite-0.34.0:
#       Successfully uninstalled llvmlite-0.34.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.51.2
#     Uninstalling numba-0.51.2:
#       Successfully uninstalled numba-0.51.2
# Successfully installed adversarial-robustness-toolbox-1.8.1 llvmlite-0.37.0 numba-0.54.1

# %% [markdown]
# ## ライブラリのインポート

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# TensorFlow with Keras.
import tensorflow as tf
import keras
from keras.models import Model
from keras.layers import Input, Dense, Flatten, Conv2D, Lambda
from keras.layers import MaxPooling2D, GlobalAveragePooling2D, Dropout
tf.compat.v1.disable_eager_execution()
from keras import backend as K

# ART
import art
from art.attacks.evasion import FastGradientMethod
from art.estimators.classification import KerasClassifier

# %% [markdown]
# ## CIFAR10のロード・前処理

# %%
# CIFAR10のロード。
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()

# CIFAR10のラベル。
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
num_classes = len(classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# 170508288/170498071 [==============================] - 11s 0us/step

# %%
# 正規化。
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# ラベルをOne-hot-vector化。
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# # Classifier(k-WTAなし)の作成

# %% [markdown]
# ## モデル定義

# %%
# モデルの定義。
inputs = Input(shape=(32, 32, 3))
x = Conv2D(64, (3, 3), padding='SAME', activation='relu')(inputs)
x = Conv2D(64, (3, 3), padding='SAME', activation='relu')(x)
x = Dropout(0.25)(x)
x = MaxPooling2D()(x)

x = Conv2D(128, (3,3), padding='SAME', activation='relu')(x)
x = Conv2D(128, (3,3), padding='SAME', activation='relu')(x)
x = Dropout(0.25)(x)
x = MaxPooling2D()(x)

x = Conv2D(256, (3,3), padding='SAME', activation='relu')(x)
x = Conv2D(256, (3,3), padding='SAME', activation='relu')(x)
x = GlobalAveragePooling2D()(x)

x = Dense(1024, activation='relu')(x)
x = Dropout(0.25)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.25)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.25)(x)
y = Dense(10, activation='softmax')(x)

model = Model(inputs, y)

# モデルのコンパイル。
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              263168
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 3,518,026
# Trainable params: 3,518,026
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 学習の実行

# %%
# 学習の実行。
model.fit(X_train, y_train,
          batch_size=512,
          epochs=30,
          validation_data=(X_test, y_test),
          shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - ETA: 0s - loss: 2.2615 - accuracy: 0.1289
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 2.2615 - accuracy: 0.1289 - val_loss: 2.1184 - val_accuracy: 0.1708
# Epoch 2/30
# 50000/50000 [==============================] - 33s 669us/sample - loss: 1.9049 - accuracy: 0.2366 - val_loss: 1.7674 - val_accuracy: 0.3191
# Epoch 3/30
# 50000/50000 [==============================] - 34s 672us/sample - loss: 1.5577 - accuracy: 0.4067 - val_loss: 1.4248 - val_accuracy: 0.4674
# Epoch 4/30
# 50000/50000 [==============================] - 33s 669us/sample - loss: 1.2942 - accuracy: 0.5223 - val_loss: 1.2124 - val_accuracy: 0.5643
# Epoch 5/30
# 50000/50000 [==============================] - 33s 665us/sample - loss: 1.1188 - accuracy: 0.5935 - val_loss: 1.1378 - val_accuracy: 0.5896
# Epoch 6/30
# 50000/50000 [==============================] - 33s 655us/sample - loss: 0.9704 - accuracy: 0.6510 - val_loss: 0.9570 - val_accuracy: 0.6605
# Epoch 7/30
# 50000/50000 [==============================] - 33s 660us/sample - loss: 0.8745 - accuracy: 0.6908 - val_loss: 0.8506 - val_accuracy: 0.7069
# Epoch 8/30
# 50000/50000 [==============================] - 33s 659us/sample - loss: 0.7742 - accuracy: 0.7281 - val_loss: 0.8574 - val_accuracy: 0.7085
# Epoch 9/30
# 50000/50000 [==============================] - 33s 660us/sample - loss: 0.6951 - accuracy: 0.7567 - val_loss: 0.7678 - val_accuracy: 0.7376
# Epoch 10/30
# 50000/50000 [==============================] - 33s 658us/sample - loss: 0.6246 - accuracy: 0.7818 - val_loss: 0.7665 - val_accuracy: 0.7379
# Epoch 11/30
# 50000/50000 [==============================] - 33s 658us/sample - loss: 0.5684 - accuracy: 0.8029 - val_loss: 0.7742 - val_accuracy: 0.7363
# Epoch 12/30
# 50000/50000 [==============================] - 33s 656us/sample - loss: 0.5130 - accuracy: 0.8228 - val_loss: 0.6962 - val_accuracy: 0.7682
# Epoch 13/30
# 50000/50000 [==============================] - 33s 657us/sample - loss: 0.4676 - accuracy: 0.8375 - val_loss: 0.6352 - val_accuracy: 0.7837
# Epoch 14/30
# 50000/50000 [==============================] - 33s 654us/sample - loss: 0.4317 - accuracy: 0.8499 - val_loss: 0.6404 - val_accuracy: 0.7814
# Epoch 15/30
# 50000/50000 [==============================] - 33s 657us/sample - loss: 0.3870 - accuracy: 0.8660 - val_loss: 0.6119 - val_accuracy: 0.7946
# Epoch 16/30
# 50000/50000 [==============================] - 33s 656us/sample - loss: 0.3509 - accuracy: 0.8788 - val_loss: 0.6183 - val_accuracy: 0.7995
# Epoch 17/30
# 50000/50000 [==============================] - 33s 654us/sample - loss: 0.3192 - accuracy: 0.8881 - val_loss: 0.6008 - val_accuracy: 0.8016
# Epoch 18/30
# 50000/50000 [==============================] - 33s 652us/sample - loss: 0.2885 - accuracy: 0.9005 - val_loss: 0.6294 - val_accuracy: 0.7986
# Epoch 19/30
# 50000/50000 [==============================] - 33s 658us/sample - loss: 0.2539 - accuracy: 0.9131 - val_loss: 0.6298 - val_accuracy: 0.8034
# Epoch 20/30
# 50000/50000 [==============================] - 33s 651us/sample - loss: 0.2236 - accuracy: 0.9221 - val_loss: 0.6503 - val_accuracy: 0.7954
# Epoch 21/30
# 50000/50000 [==============================] - 33s 655us/sample - loss: 0.2113 - accuracy: 0.9274 - val_loss: 0.6319 - val_accuracy: 0.8120
# Epoch 22/30
# 50000/50000 [==============================] - 33s 655us/sample - loss: 0.1859 - accuracy: 0.9360 - val_loss: 0.6361 - val_accuracy: 0.8088
# Epoch 23/30
# 50000/50000 [==============================] - 33s 657us/sample - loss: 0.1843 - accuracy: 0.9363 - val_loss: 0.6320 - val_accuracy: 0.8128
# Epoch 24/30
# 50000/50000 [==============================] - 33s 656us/sample - loss: 0.1531 - accuracy: 0.9470 - val_loss: 0.6676 - val_accuracy: 0.8089
# Epoch 25/30
# 50000/50000 [==============================] - 33s 658us/sample - loss: 0.1286 - accuracy: 0.9553 - val_loss: 0.6717 - val_accuracy: 0.8129
# Epoch 26/30
# 50000/50000 [==============================] - 33s 655us/sample - loss: 0.1259 - accuracy: 0.9567 - val_loss: 0.7262 - val_accuracy: 0.8083
# Epoch 27/30
# 50000/50000 [==============================] - 33s 655us/sample - loss: 0.1074 - accuracy: 0.9627 - val_loss: 0.7894 - val_accuracy: 0.7957
# Epoch 28/30
# 50000/50000 [==============================] - 33s 652us/sample - loss: 0.1181 - accuracy: 0.9588 - val_loss: 0.7559 - val_accuracy: 0.8073
# Epoch 29/30
# 50000/50000 [==============================] - 33s 658us/sample - loss: 0.1012 - accuracy: 0.9655 - val_loss: 0.7395 - val_accuracy: 0.8113
# Epoch 30/30
# 50000/50000 [==============================] - 33s 654us/sample - loss: 0.0963 - accuracy: 0.9675 - val_loss: 0.7760 - val_accuracy: 0.8071

# %% [markdown]
# ## モデルの精度評価

# %%
model.evaluate(X_test, y_test)
# Out:
# [0.7760056887865067, 0.8071]

# %% [markdown]
# # Classifier(k-WTAあり)の作成

# %% [markdown]
# ## k-WTAの作成

# %%
class KWTA(tf.keras.layers.Layer):
  def __init__(self, k, **kwargs) :
    super().__init__(**kwargs)
    self.k = k

  def call(self, x):
    topk = tf.math.top_k(x[0], k=self.k)   # 上位k個の値を抽出
    topk_min = K.min(topk.values)         # topkの最小値を抽出
    comp = tf.dtypes.cast(x >= topk_min, tf.float32)   # topkの最小値以上の値の部分を1, より小さい値の部分を0にしたTensorを生成
    return tf.math.multiply(x,comp)        # x * compより、topkの最小値以上の値のみそのまま、他は0になるようにする

# %% [markdown]
# ## モデル定義

# %%
# モデルの定義。
inputs = Input(shape=(32, 32, 3))
x = Conv2D(64, (3, 3), padding='SAME', activation='relu')(inputs)
x = Conv2D(64, (3, 3), padding='SAME', activation='relu')(x)
x = Dropout(0.25)(x)
x = MaxPooling2D()(x)

x = Conv2D(128, (3,3), padding='SAME', activation='relu')(x)
x = Conv2D(128, (3,3), padding='SAME', activation='relu')(x)
x = Dropout(0.25)(x)
x = MaxPooling2D()(x)

x = Conv2D(256, (3,3), padding='SAME', activation='relu')(x)
x = Conv2D(256, (3,3), padding='SAME', activation='relu')(x)
x = GlobalAveragePooling2D()(x)

x = Dense(1024)(x)
x = KWTA(512)(x)
x = Dropout(0.25)(x)
x = Dense(1024)(x)
x = KWTA(512)(x)
x = Dropout(0.25)(x)
x = Dense(1024)(x)
x = KWTA(512)(x)
x = Dropout(0.25)(x)
y = Dense(10, activation='softmax')(x)

model_kwta = Model(inputs, y)

# モデルのコンパイル。
model_kwta.compile(optimizer=tf.keras.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model_kwta.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              263168
# _________________________________________________________________
# kwta (KWTA)                  (None, 1024)              0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# kwta_1 (KWTA)                (None, 1024)              0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# kwta_2 (KWTA)                (None, 1024)              0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 3,518,026
# Trainable params: 3,518,026
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 学習の実行

# %%
# 学習の実行。
model_kwta.fit(X_train, y_train,
          batch_size=512,
          epochs=30,
          validation_data=(X_test, y_test),
          shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - ETA: 0s - loss: 2.1231 - accuracy: 0.1730
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 50000/50000 [==============================] - 34s 675us/sample - loss: 2.1231 - accuracy: 0.1730 - val_loss: 2.0295 - val_accuracy: 0.1896
# Epoch 2/30
# 50000/50000 [==============================] - 33s 661us/sample - loss: 1.7949 - accuracy: 0.2780 - val_loss: 1.6298 - val_accuracy: 0.3726
# Epoch 3/30
# 50000/50000 [==============================] - 33s 666us/sample - loss: 1.4510 - accuracy: 0.4415 - val_loss: 1.4035 - val_accuracy: 0.4756
# Epoch 4/30
# 50000/50000 [==============================] - 33s 662us/sample - loss: 1.2203 - accuracy: 0.5501 - val_loss: 1.2976 - val_accuracy: 0.5211
# Epoch 5/30
# 50000/50000 [==============================] - 33s 668us/sample - loss: 1.0618 - accuracy: 0.6119 - val_loss: 1.3140 - val_accuracy: 0.5151
# Epoch 6/30
# 50000/50000 [==============================] - 33s 667us/sample - loss: 0.9372 - accuracy: 0.6628 - val_loss: 1.0317 - val_accuracy: 0.6314
# Epoch 7/30
# 50000/50000 [==============================] - 34s 671us/sample - loss: 0.8111 - accuracy: 0.7129 - val_loss: 0.9077 - val_accuracy: 0.6802
# Epoch 8/30
# 50000/50000 [==============================] - 33s 668us/sample - loss: 0.7100 - accuracy: 0.7500 - val_loss: 0.7469 - val_accuracy: 0.7417
# Epoch 9/30
# 50000/50000 [==============================] - 33s 670us/sample - loss: 0.6808 - accuracy: 0.7597 - val_loss: 0.8667 - val_accuracy: 0.7032
# Epoch 10/30
# 50000/50000 [==============================] - 33s 664us/sample - loss: 0.5936 - accuracy: 0.7944 - val_loss: 0.7066 - val_accuracy: 0.7543
# Epoch 11/30
# 50000/50000 [==============================] - 33s 667us/sample - loss: 0.5064 - accuracy: 0.8241 - val_loss: 0.8577 - val_accuracy: 0.7199
# Epoch 12/30
# 50000/50000 [==============================] - 33s 661us/sample - loss: 0.4722 - accuracy: 0.8358 - val_loss: 0.6495 - val_accuracy: 0.7835
# Epoch 13/30
# 50000/50000 [==============================] - 33s 668us/sample - loss: 0.4255 - accuracy: 0.8500 - val_loss: 0.7414 - val_accuracy: 0.7538
# Epoch 14/30
# 50000/50000 [==============================] - 33s 664us/sample - loss: 0.3749 - accuracy: 0.8704 - val_loss: 0.6361 - val_accuracy: 0.7875
# Epoch 15/30
# 50000/50000 [==============================] - 33s 665us/sample - loss: 0.3268 - accuracy: 0.8865 - val_loss: 0.6318 - val_accuracy: 0.7953
# Epoch 16/30
# 50000/50000 [==============================] - 33s 661us/sample - loss: 0.2986 - accuracy: 0.8950 - val_loss: 0.6684 - val_accuracy: 0.7894
# Epoch 17/30
# 50000/50000 [==============================] - 33s 664us/sample - loss: 0.2963 - accuracy: 0.8968 - val_loss: 0.6255 - val_accuracy: 0.7977
# Epoch 18/30
# 50000/50000 [==============================] - 33s 662us/sample - loss: 0.2471 - accuracy: 0.9142 - val_loss: 0.6754 - val_accuracy: 0.7895
# Epoch 19/30
# 50000/50000 [==============================] - 33s 660us/sample - loss: 0.2529 - accuracy: 0.9129 - val_loss: 0.7272 - val_accuracy: 0.7722
# Epoch 20/30
# 50000/50000 [==============================] - 32s 645us/sample - loss: 0.2322 - accuracy: 0.9197 - val_loss: 0.7016 - val_accuracy: 0.7894
# Epoch 21/30
# 50000/50000 [==============================] - 33s 653us/sample - loss: 0.1783 - accuracy: 0.9380 - val_loss: 0.7269 - val_accuracy: 0.7950
# Epoch 22/30
# 50000/50000 [==============================] - 33s 651us/sample - loss: 0.1641 - accuracy: 0.9428 - val_loss: 0.7170 - val_accuracy: 0.7911
# Epoch 23/30
# 50000/50000 [==============================] - 33s 654us/sample - loss: 0.1538 - accuracy: 0.9466 - val_loss: 0.8110 - val_accuracy: 0.7832
# Epoch 24/30
# 50000/50000 [==============================] - 32s 650us/sample - loss: 0.1448 - accuracy: 0.9490 - val_loss: 0.7962 - val_accuracy: 0.7890
# Epoch 25/30
# 50000/50000 [==============================] - 33s 655us/sample - loss: 0.1565 - accuracy: 0.9453 - val_loss: 0.7356 - val_accuracy: 0.8017
# Epoch 26/30
# 50000/50000 [==============================] - 33s 652us/sample - loss: 0.1355 - accuracy: 0.9531 - val_loss: 0.8133 - val_accuracy: 0.7978
# Epoch 27/30
# 50000/50000 [==============================] - 33s 654us/sample - loss: 0.1204 - accuracy: 0.9586 - val_loss: 0.8773 - val_accuracy: 0.7845
# Epoch 28/30
# 50000/50000 [==============================] - 33s 650us/sample - loss: 0.1180 - accuracy: 0.9594 - val_loss: 0.7450 - val_accuracy: 0.8119
# Epoch 29/30
# 50000/50000 [==============================] - 33s 654us/sample - loss: 0.1118 - accuracy: 0.9613 - val_loss: 0.7667 - val_accuracy: 0.8082
# Epoch 30/30
# 50000/50000 [==============================] - 33s 650us/sample - loss: 0.1134 - accuracy: 0.9608 - val_loss: 0.7685 - val_accuracy: 0.7993

# %% [markdown]
# ## モデルの精度評価

# %%
model_kwta.evaluate(X_test, y_test)
# Out:
# [0.7803472219467164, 0.8026]

# %% [markdown]
# # 敵対的攻撃

# %% [markdown]
# ## 非標的型攻撃としてのFGSMによる摂動を作成
# 以下、この摂動を上乗せした画像のことを「敵対的画像」と呼ぶ。

# %%
# 入力データの特徴量の最小値・最大値を指定。
# 特徴量は0.0～1.0の範囲に収まるように正規化しているため、最小値は0.0、最大値は1.0とする。
min_pixel_value = 0.0
max_pixel_value = 1.0

# %% [markdown]
# ### k-WTAなし

# %%
# モデルをART Keras Classifierでラップ。
classifier = KerasClassifier(model=model, clip_values=(min_pixel_value, max_pixel_value), use_logits=False)
# FGSMインスタンスの作成。
attack = FastGradientMethod(estimator=classifier, eps=0.10, targeted=False)
# 敵対的サンプルの生成（ベース画像はテストデータとする）。
X_adv = attack.generate(x=X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '

# %% [markdown]
# ### k-WTAあり

# %%
classifier_kwta = KerasClassifier(model=model_kwta, clip_values=(min_pixel_value, max_pixel_value), use_logits=False)
attack_kwta = FastGradientMethod(estimator=classifier_kwta, eps=0.10, targeted=False)
X_adv_kwta = attack_kwta.generate(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '

# %% [markdown]
# ## 敵対的画像に対するモデルの精度評価

# %% [markdown]
# ### k-WTAなし

# %%
model.evaluate(X_adv, y_test)
# Out:
# [7.944170335388184, 0.1025]

# %% [markdown]
# ### k-WTAあり

# %%
model_kwta.evaluate(X_adv_kwta, y_test)
# Out:
# [8.029034226989745, 0.1237]
