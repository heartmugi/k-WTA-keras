# %% [markdown]
# # 準備

# %% [markdown]
# ## artのインストール

# %%
# !pip3 install adversarial-robustness-toolbox
# Out:
# Requirement already satisfied: adversarial-robustness-toolbox in /usr/local/lib/python3.7/dist-packages (1.8.1)
# Requirement already satisfied: scikit-learn<1.1.0,>=0.22.2 in /usr/local/lib/python3.7/dist-packages (from adversarial-robustness-toolbox) (0.22.2.post1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from adversarial-robustness-toolbox) (1.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from adversarial-robustness-toolbox) (4.62.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from adversarial-robustness-toolbox) (57.4.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.7/dist-packages (from adversarial-robustness-toolbox) (1.19.5)
# Requirement already satisfied: numba>=0.53.1 in /usr/local/lib/python3.7/dist-packages (from adversarial-robustness-toolbox) (0.54.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from adversarial-robustness-toolbox) (1.15.0)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in /usr/local/lib/python3.7/dist-packages (from numba>=0.53.1->adversarial-robustness-toolbox) (0.37.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<1.1.0,>=0.22.2->adversarial-robustness-toolbox) (1.0.1)

# %% [markdown]
# ## ライブラリのインポート

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# TensorFlow with Keras.
import tensorflow as tf
import keras
from keras.models import Model
from keras.layers import Input, Dense, Flatten, Conv2D, Lambda, Flatten
from keras.layers import MaxPooling2D, GlobalAveragePooling2D, Dropout
tf.compat.v1.disable_eager_execution()
from keras import backend as K

# ART
import art
from art.attacks.evasion import FastGradientMethod
from art.estimators.classification import KerasClassifier

# %% [markdown]
# ## CIFAR10のロード・前処理

# %%
# CIFAR10のロード。
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# CIFAR10のラベル。
classes = [str(i) for i in range(10)]
num_classes = len(classes)

# %%
# 正規化。
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# 次元追加
X_train = np.expand_dims(X_train, axis=3)
X_test = np.expand_dims(X_test, axis=3)

# ラベルをOne-hot-vector化。
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# # Classifier(k-WTAなし)の作成

# %% [markdown]
# ## モデル定義

# %%
# モデルの定義。
inputs = Input(shape=(28, 28, 1))
x = Conv2D(32, (3, 3), padding='SAME', activation='relu')(inputs)
x = Conv2D(32, (3, 3), padding='SAME', activation='relu')(x)
x = Dropout(0.25)(x)
x = MaxPooling2D()(x)

x = Conv2D(64, (3,3), padding='SAME', activation='relu')(x)
x = Conv2D(64, (3,3), padding='SAME', activation='relu')(x)
x = Dropout(0.25)(x)
x = MaxPooling2D()(x)

x = Conv2D(128, (3,3), padding='SAME', activation='relu')(x)
x = Conv2D(128, (3,3), padding='SAME', activation='relu')(x)
x = GlobalAveragePooling2D()(x)

x = Dense(1024, activation='relu')(x)
x = Dropout(0.25)(x)
y = Dense(10, activation='softmax')(x)

model = Model(inputs, y)

# モデルのコンパイル。
model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 28, 28, 32)        320
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 28, 28, 32)        9248
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 28, 28, 32)        0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 14, 14, 64)        18496
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 14, 14, 64)        36928
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 7, 7, 128)         73856
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 7, 7, 128)         147584
# _________________________________________________________________
# global_average_pooling2d_7 ( (None, 128)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1024)              132096
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 10)                10250
# =================================================================
# Total params: 428,778
# Trainable params: 428,778
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %% [markdown]
# ## 学習の実行

# %% [markdown]
# ## モデルの精度評価

# %%
# 学習の実行。
model.fit(X_train, y_train,
          batch_size=512,
          epochs=10,
          validation_data=(X_test, y_test),
          shuffle=True)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 59904/60000 [============================>.] - ETA: 0s - loss: 1.0298 - accuracy: 0.6319
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 60000/60000 [==============================] - 16s 268us/sample - loss: 1.0286 - accuracy: 0.6324 - val_loss: 0.2879 - val_accuracy: 0.9259
# Epoch 2/10
# 60000/60000 [==============================] - 15s 254us/sample - loss: 0.1840 - accuracy: 0.9442 - val_loss: 0.1376 - val_accuracy: 0.9697
# Epoch 3/10
# 60000/60000 [==============================] - 15s 250us/sample - loss: 0.1244 - accuracy: 0.9627 - val_loss: 0.1198 - val_accuracy: 0.9729
# Epoch 4/10
# 60000/60000 [==============================] - 15s 248us/sample - loss: 0.0916 - accuracy: 0.9720 - val_loss: 0.0849 - val_accuracy: 0.9815
# Epoch 5/10
# 60000/60000 [==============================] - 15s 246us/sample - loss: 0.0761 - accuracy: 0.9759 - val_loss: 0.0699 - val_accuracy: 0.9836
# Epoch 6/10
# 60000/60000 [==============================] - 15s 250us/sample - loss: 0.0600 - accuracy: 0.9811 - val_loss: 0.0748 - val_accuracy: 0.9832
# Epoch 7/10
# 60000/60000 [==============================] - 15s 248us/sample - loss: 0.0550 - accuracy: 0.9833 - val_loss: 0.0703 - val_accuracy: 0.9813
# Epoch 8/10
# 60000/60000 [==============================] - 15s 251us/sample - loss: 0.0479 - accuracy: 0.9857 - val_loss: 0.0533 - val_accuracy: 0.9856
# Epoch 9/10
# 60000/60000 [==============================] - 15s 246us/sample - loss: 0.0439 - accuracy: 0.9866 - val_loss: 0.0671 - val_accuracy: 0.9857
# Epoch 10/10
# 60000/60000 [==============================] - 15s 246us/sample - loss: 0.0410 - accuracy: 0.9876 - val_loss: 0.0403 - val_accuracy: 0.9905

# %%
model.evaluate(X_test, y_test)
# Out:
# [0.04027113765515387, 0.9905]

# %% [markdown]
# # Classifier(k-WTAあり)の作成

# %% [markdown]
# ## k-WTAの作成

# %%
class KWTA(tf.keras.layers.Layer):
  def __init__(self, k=None, **kwargs) :
    super().__init__(**kwargs)
    self.k = k

  def call(self, x):
    n = x[0].shape[0]
    if self.k == None:
            k = n * 1 // 10
    else:
            k = self.k
    topk = tf.math.top_k(x[0], k=k)   # 上位k個の値を抽出
    topk_min = K.min(topk.values)         # topkの最小値を抽出
    comp = tf.dtypes.cast(x >= topk_min, tf.float32)   # topkの最小値以上の値の部分を1, より小さい値の部分を0にしたTensorを生成
    return tf.math.multiply(x,comp)        # x * compより、topkの最小値以上の値のみそのまま、他は0になるようにする

class KWTA2D(tf.keras.layers.Layer):
    def __init__(self, k=None, **kwargs):
        super().__init__(**kwargs)
        self.k = k
        
    def call(self, x):
        n = x[0].shape[0] * x[0].shape[1] * x[0].shape[2]
        if self.k == None:
            k = n * 1 // 10
        else:
            k = self.k
        x_flatten = tf.reshape(x[0],  [n])
        topk = tf.math.top_k(x_flatten, k=k)
        topk_min = K.min(topk.values) 
        comp = tf.dtypes.cast(x >= topk_min, tf.float32)
        return tf.math.multiply(x,comp)

# %% [markdown]
# ## モデル定義

# %%
# モデルの定義。
inputs = Input(shape=(28, 28, 1))
x = Conv2D(32, (3, 3), padding='SAME')(inputs)
x = KWTA2D()(x)
x = Conv2D(32, (3, 3), padding='SAME')(x)
x = KWTA2D()(x)
x = Dropout(0.25)(x)
x = MaxPooling2D()(x)

x = Conv2D(64, (3,3), padding='SAME')(x)
x = KWTA2D()(x)
x = Conv2D(64, (3,3), padding='SAME')(x)
x = KWTA2D()(x)
x = Dropout(0.25)(x)
x = MaxPooling2D()(x)

x = Conv2D(128, (3,3), padding='SAME')(x)
x = KWTA2D()(x)
x = Conv2D(128, (3,3), padding='SAME')(x)
x = KWTA2D()(x)
x = GlobalAveragePooling2D()(x)

x = Dense(1024)(x)
x = KWTA()(x)
x = Dropout(0.25)(x)
y = Dense(10, activation='softmax')(x)

model_kwta = Model(inputs, y)

# モデルのコンパイル。
model_kwta.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model_kwta.summary()
# Out:
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 28, 28, 32)        320
# _________________________________________________________________
# kwt_a2d (KWTA2D)             (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 28, 28, 32)        9248
# _________________________________________________________________
# kwt_a2d_1 (KWTA2D)           (None, 28, 28, 32)        0
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 28, 28, 32)        0
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 14, 14, 64)        18496
# _________________________________________________________________
# kwt_a2d_2 (KWTA2D)           (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 14, 14, 64)        36928
# _________________________________________________________________
# kwt_a2d_3 (KWTA2D)           (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 7, 7, 128)         73856
# _________________________________________________________________
# kwt_a2d_4 (KWTA2D)           (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 7, 7, 128)         147584
# _________________________________________________________________
# kwt_a2d_5 (KWTA2D)           (None, 7, 7, 128)         0
# _________________________________________________________________
# global_average_pooling2d_8 ( (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1024)              132096
# _________________________________________________________________
# kwta (KWTA)                  (None, 1024)              0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                10250
# =================================================================
# Total params: 428,778
# Trainable params: 428,778
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %% [markdown]
# ## 学習の実行

# %%
# 学習の実行。
model_kwta.fit(X_train, y_train,
          batch_size=512,
          epochs=10,
          validation_data=(X_test, y_test),
          shuffle=True)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - ETA: 0s - loss: 2.2562 - accuracy: 0.1886
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 60000/60000 [==============================] - 19s 311us/sample - loss: 2.2562 - accuracy: 0.1886 - val_loss: 2.2283 - val_accuracy: 0.1664
# Epoch 2/10
# 60000/60000 [==============================] - 17s 289us/sample - loss: 2.0811 - accuracy: 0.2451 - val_loss: 1.7615 - val_accuracy: 0.3580
# Epoch 3/10
# 60000/60000 [==============================] - 17s 288us/sample - loss: 0.9498 - accuracy: 0.6645 - val_loss: 0.4896 - val_accuracy: 0.8518
# Epoch 4/10
# 60000/60000 [==============================] - 17s 291us/sample - loss: 0.2888 - accuracy: 0.9145 - val_loss: 0.1789 - val_accuracy: 0.9524
# Epoch 5/10
# 60000/60000 [==============================] - 18s 292us/sample - loss: 0.1393 - accuracy: 0.9594 - val_loss: 0.1090 - val_accuracy: 0.9727
# Epoch 6/10
# 60000/60000 [==============================] - 17s 290us/sample - loss: 0.1038 - accuracy: 0.9688 - val_loss: 0.0832 - val_accuracy: 0.9816
# Epoch 7/10
# 60000/60000 [==============================] - 17s 290us/sample - loss: 0.0784 - accuracy: 0.9754 - val_loss: 0.0578 - val_accuracy: 0.9851
# Epoch 8/10
# 60000/60000 [==============================] - 17s 289us/sample - loss: 0.0580 - accuracy: 0.9825 - val_loss: 0.0632 - val_accuracy: 0.9868
# Epoch 9/10
# 60000/60000 [==============================] - 17s 289us/sample - loss: 0.0524 - accuracy: 0.9843 - val_loss: 0.0415 - val_accuracy: 0.9894
# Epoch 10/10
# 60000/60000 [==============================] - 17s 290us/sample - loss: 0.0420 - accuracy: 0.9872 - val_loss: 0.0341 - val_accuracy: 0.9911

# %% [markdown]
# ## モデルの精度評価

# %%
model_kwta.evaluate(X_test, y_test)
# Out:
# [0.03130911228219047, 0.991]

# %% [markdown]
# # 敵対的攻撃

# %% [markdown]
# ## 非標的型攻撃としてのFGSMによる摂動を作成
# 以下、この摂動を上乗せした画像のことを「敵対的画像」と呼ぶ。

# %%
# 入力データの特徴量の最小値・最大値を指定。
# 特徴量は0.0～1.0の範囲に収まるように正規化しているため、最小値は0.0、最大値は1.0とする。
min_pixel_value = 0.0
max_pixel_value = 1.0

# %% [markdown]
# ### k-WTAなし

# %%
# モデルをART Keras Classifierでラップ。
classifier = KerasClassifier(model=model, clip_values=(min_pixel_value, max_pixel_value), use_logits=False)
# FGSMインスタンスの作成。
attack = FastGradientMethod(estimator=classifier, eps=0.20, targeted=False)
# 敵対的サンプルの生成（ベース画像はテストデータとする）。
X_adv = attack.generate(x=X_test)

# %% [markdown]
# ### k-WTAあり

# %%
classifier_kwta = KerasClassifier(model=model_kwta, clip_values=(min_pixel_value, max_pixel_value), use_logits=False)
attack_kwta = FastGradientMethod(estimator=classifier_kwta, eps=0.20, targeted=False)
X_adv_kwta = attack_kwta.generate(X_test)

# %% [markdown]
# ## 敵対的画像に対するモデルの精度評価

# %% [markdown]
# ### k-WTAなし

# %%
model.evaluate(X_adv, y_test)
# Out:
# [2.4208896518707275, 0.2452]

# %% [markdown]
# ### k-WTAあり

# %%
model_kwta.evaluate(X_adv_kwta, y_test)
# Out:
# [0.4960899344563484, 0.8426]
